# %%
# RRCP (12/08/2026): Redes Neuronales
import torch                    # 1. PyTorch principal.
import torch.nn as nn           # 2. Módulos de redes (capas, funciones de activación).
import torch.optim as optim     # 3. Optimización (Adam, SGD...).
import numpy as np              # 4. Para datos de ejemplo.

# %%
"""
┌─────────────────────────────────────────────────────────────┐
│                  REDES NEURONALES CON PYTORCH               │
└─────────────────────────────────────────────────────────────┘
                              │
                              ▼
┌─────────────────────────────────────────────────────────────┐
│ 1. PREPARACIÓN DE DATOS                                     │
│                                                             │
│    NumPy                                                    │
│      │                                                      │
│      ├── X_np → 100 registros × 4 características           │
│      │                                                      │
│      └── y_np → 100 etiquetas binarias (0 / 1)              │
│                                                             │
│    Conversión a tensores PyTorch                            │
│      │                                                      │
│      ├── X → Tensor [100, 4]                                │
│      └── y → Tensor [100]                                   │
└─────────────────────────────────────────────────────────────┘
                              │
                              ▼
┌─────────────────────────────────────────────────────────────┐
│ 2. CONSTRUCCIÓN DE LA RED NEURONAL SIMPLE                   │
│                                                             │
│             4 características de entrada                    │
│                       │                                     │
│                       ▼                                     │
│               ┌───────────────┐                             │
│               │ Capa oculta   │                             │
│               │ 4 → 8         │                             │
│               │ nn.Linear     │                             │
│               └───────┬───────┘                             │
│                       │                                     │
│                       ▼                                     │
│                 ReLU (activación)                           │
│                       │                                     │
│                       ▼                                     │
│               ┌───────────────┐                             │
│               │ Capa salida   │                             │
│               │ 8 → 1         │                             │
│               │ nn.Linear     │                             │
│               └───────┬───────┘                             │
│                       │                                     │
│                       ▼                                     │
│                Sigmoid (0 → 1)                              │
│                       │                                     │
│                       ▼                                     │
│                 Probabilidad                                │
└─────────────────────────────────────────────────────────────┘
                              │
                              ▼
┌─────────────────────────────────────────────────────────────┐
│ 3. CONFIGURACIÓN DEL ENTRENAMIENTO                          │
│                                                             │
│    Función de pérdida                                       │
│         │                                                   │
│         └── BCELoss                                         │
│                                                             │
│    Optimizador                                              │
│         │                                                   │
│         └── Adam                                            │
│              learning rate = 0.001                          │
└─────────────────────────────────────────────────────────────┘
                              │
                              ▼
┌─────────────────────────────────────────────────────────────┐
│ 4. ENTRENAMIENTO                                            │
│                                                             │
│    Dataset → DataLoader                                     │
│                       │                                     │
│                       ▼                                     │
│              Mini-batches de 10                             │
│                       │                                     │
│                       ▼                                     │
│                  FORWARD                                    │
│                       │                                     │
│                       ▼                                     │
│                Predicción y_pred                            │
│                       │                                     │
│                       ▼                                     │
│              Calcular pérdida                               │
│                  BCELoss                                    │
│                       │                                     │
│                       ▼                                     │
│              Backpropagation                                │
│                  loss.backward()                            │
│                       │                                     │
│                       ▼                                     │
│              Actualizar pesos                               │
│                  optimizer.step()                           │
│                       │                                     │
│                       ▼                                     │
│                Repetir 10 épocas                            │
└─────────────────────────────────────────────────────────────┘
                              │
                              ▼
┌─────────────────────────────────────────────────────────────┐
│ 5. EVALUACIÓN                                               │
│                                                             │
│    modelo(X)                                                │
│       │                                                     │
│       ▼                                                     │
│    Probabilidades                                           │
│       │                                                     │
│       ▼                                                     │
│    Umbral 0.5                                               │
│       │                                                     │
│       ▼                                                     │
│    Predicciones 0 / 1                                       │
│       │                                                     │
│       ▼                                                     │
│    Comparación con y                                        │
│       │                                                     │
│       ▼                                                     │
│    Accuracy                                                 │
│                                                             │
│    Resultado observado: 51.00%                              │
└─────────────────────────────────────────────────────────────┘
                              │
                              ▼
                 ┌───────────────────────────┐
                 │ EXPERIMENTACIÓN DINÁMICA   │
                 └─────────────┬─────────────┘
                               │
                               ▼
┌─────────────────────────────────────────────────────────────┐
│ 6. RED NEURONAL DINÁMICA                                    │
│                                                             │
│              IntSlider: 1 ─────────────── 5                 │
│                         │                                   │
│                         ▼                                   │
│                Número de capas ocultas                      │
│                         │                                   │
│                         ▼                                   │
│                   RedDyn(4, 4, cap)                         │
│                         │                                   │
│                         ▼                                   │
│              ┌──────────────────────┐                       │
│              │ Entrada: 4 variables │                       │
│              └──────────┬───────────┘                       │
│                         │                                   │
│                         ▼                                   │
│              ┌──────────────────────┐                       │
│              │ Capa oculta: 4       │                       │
│              │ neuronas + ReLU      │                       │
│              └──────────┬───────────┘                       │
│                         │                                   │
│                  ┌──────┴──────┐                            │
│                  │             │                            │
│                  ▼             ▼                            │
│             Más capas      Según slider                     │
│             ocultas        (1 a 5)                          │
│                  │             │                            │
│                  └──────┬──────┘                            │
│                         ▼                                   │
│                 Capa salida: 1                              │
│                         │                                   │
│                         ▼                                   │
│                     Sigmoid                                 │
└─────────────────────────────────────────────────────────────┘
                              │
                              ▼
┌─────────────────────────────────────────────────────────────┐
│ 7. ENTRENAMIENTO Y COMPARACIÓN                              │
│                                                             │
│    Para cada número de capas:                               │
│                                                             │
│       1. Crear RedDyn                                       │
│       2. BCELoss                                            │
│       3. Adam (lr = 0.001)                                  │
│       4. Entrenar durante 3 épocas                          │
│       5. Obtener predicciones                               │
│       6. Aplicar umbral 0.5                                 │
│       7. Calcular Accuracy                                  │
│                                                             │
│                  ↓                                          │
│                                                             │
│       "Precision con X capas: XX.XX%"                       │
└─────────────────────────────────────────────────────────────┘
"""

# %%
# 1. Creamos datos aleatorios con NumPy
X_np = np.random.rand(100,4).astype(np.float32) # 100x4 entradas, float32 para PyTorch
y_np = np.random.randint(0, 2, size = (100,)).astype(np.int64) # 100 etiquetas binarias

# 2. Convertimos a tensores de PyTorch
X = torch.from_numpy(X_np) # Tensor de tamaño [100, 4]
y = torch.from_numpy(y_np) # Tensor de tamaño [100]

# %%
class RedSimple(nn.Module):
    def __init__(self, n_entradas, n_ocultas, n_salidas):
        super().__init__()
        # 1. Capa oculta
        self.hidden = nn.Linear(n_entradas, n_ocultas)
        # 2. Capa de salida
        self.output = nn.Linear(n_ocultas, n_salidas)
        # 3. Funcion de activación ReLU
        self.relu = nn.ReLU()
        # 4. Sigmoide para la salida binaria
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # 5. Pasos hacia adelante: entrada > oculta > activacion > salida > sigmoide
        x = self.hidden(x)
        x = self.relu(x)
        x = self.output(x)
        x = self.sigmoid(x).squeeze(1)
        return x

# 6. Creamos una instancia: 4 entradas > 8 neuronas ocultas > 1 salida
modelo = RedSimple(n_entradas = 4, n_ocultas = 8, n_salidas = 1)

# %%
# 1. Loss: entropía cruzada binaria para entradas de probabilidad
criterion = nn.BCELoss()
# 2. Optimizador Adam con tasa de aprendizaje po defecto
optimizer = optim.Adam(modelo.parameters(), lr = 0.001)

# %%
n_epochs = 10
batch_size = 10
dataset = torch.utils.data.TensorDataset(X, y)
louder = torch.utils.data.DataLoader(dataset, batch_size = batch_size, shuffle = True)

for epoch in range(n_epochs):
    for X_batch, y_batch in louder:
        # 1. Forward
        y_pred = modelo(X_batch)
        # 2. Calcular pérdida
        loss = criterion(y_pred, y_batch.float())
        # 3. Backprop y optimización
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # 4. Mostrar progreso por época
    print(f"Epoch {epoch + 1}/{n_epochs}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1/10, Loss: 0.6740
# Epoch 2/10, Loss: 0.7578
# Epoch 3/10, Loss: 0.6780
# Epoch 4/10, Loss: 0.6482
# Epoch 5/10, Loss: 0.7988
# Epoch 6/10, Loss: 0.6730
# Epoch 7/10, Loss: 0.7130
# Epoch 8/10, Loss: 0.7006
# Epoch 9/10, Loss: 0.7031
# Epoch 10/10, Loss: 0.7470

# %%
with torch.no_grad():
    y_prob = modelo(X)                      # 1. Predicciones de probabilidad
    y_pred = (y_prob > 0.5).int()           # 2. Convertir a 0/1 con umbral 0.5
    accuracy = (y_pred == y).float().mean() # 3. Proporción de aciertos.
    print(f"Precisión del modelo: {accuracy * 100:.2f}%")
# Out:
# Precisión del modelo: 51.00%

# %%
# Mostrar las capas en orden y sus tamaños.
print(modelo)
# Out:
# RedSimple(
#   (hidden): Linear(in_features=4, out_features=8, bias=True)
#   (output): Linear(in_features=8, out_features=1, bias=True)
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
# )

# %%
import ipywidgets as widgets

capas_widget = widgets.IntSlider(min = 1, max = 5, descripcion = 'Capas Ocultas: ')

def probar_pytorch(cap):
    # 1. Creamos secuencia de capas según slider.
    class RedDyn(nn.Module):
        def __init__(self, n_entradas, n_ocultas, n_capas):
                super().__init__()
                self.layers = nn.ModuleList()
                self.layers.append(nn.Linear(n_entradas, n_ocultas))
                for _ in range(n_capas - 1):
                     self.layers.append(nn.Linear(n_ocultas, n_ocultas))
                self.out = nn.Linear(n_ocultas, 1)
                self.relu = nn.ReLU()
                self.sig = nn.Sigmoid()
        def forward(self, x):
            for layer in self.layers:
                    x = self.relu(layer(x))
            x = self.sig(self.out(x)).squeeze(1)
            return x

    model = RedDyn(4, 4, cap) # 4 caracteristicas, 4 neuronas por capa
    crit = nn.BCELoss()
    opt = optim.Adam(model.parameters(), lr = 0.001)

    # Entrenamiento rápido (3 épocas)
    for _ in range(3):
          y_p = model(X)
          l = crit(y_p, y.float())
          opt.zero_grad(); l.backward(); opt.step()

    # Evaluacion
    with torch.no_grad():
        y_p = model(X)
        preds = (y_p > 0.5).int()
        acc = (preds == y).float().mean()

    print(f"Precision con {cap} capas: {acc*100:.2f}%")

widgets.interactive(probar_pytorch, cap = capas_widget)
# Out:
# interactive(children=(IntSlider(value=1, description='cap', max=5, min=1), Output()), _dom_classes=('widget-in…
